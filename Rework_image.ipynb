# %%
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from ipywidgets import interact, interactive, fixed, interact_manual, widgets
# %matplotlib inline
from dep.fonctions import crop_image

# %% [markdown]
# # Pour cropper les images

# %%
imgs =glob.glob('assets/img/*.png')
for i, im in enumerate(imgs):
    if ('3D' in im) and 'cropped' not in im:
        print(i, im)
# Out:
# 0 assets/img\graph3D_charges_cas_1_RFx_kN.png
# 2 assets/img\graph3D_charges_cas_1_RFy_kN.png
# 4 assets/img\graph3D_charges_cas_1_RFz_kN.png
# 6 assets/img\graph3D_charges_cas_2_RFx_kN.png
# 8 assets/img\graph3D_charges_cas_2_RFy_kN.png
# 10 assets/img\graph3D_charges_cas_2_RFz_kN.png
# 12 assets/img\graph3D_charges_cas_3_RFx_kN.png
# 14 assets/img\graph3D_charges_cas_3_RFy_kN.png
# 16 assets/img\graph3D_charges_cas_3_RFz_kN.png
# 18 assets/img\graph3D_charges_cas_4_RFx_kN.png
# 20 assets/img\graph3D_charges_cas_4_RFy_kN.png
# 22 assets/img\graph3D_charges_cas_4_RFz_kN.png
# 24 assets/img\graph3D_charges_cas_5_RFx_kN.png
# 26 assets/img\graph3D_charges_cas_5_RFy_kN.png
# 28 assets/img\graph3D_charges_cas_5_RFz_kN.png
# 30 assets/img\graph3D_charges_cas_6_RFx_kN.png
# 32 assets/img\graph3D_charges_cas_6_RFy_kN.png
# 34 assets/img\graph3D_charges_cas_6_RFz_kN.png
# 36 assets/img\graph3D_charges_cas_7_RFx_kN.png
# 38 assets/img\graph3D_charges_cas_7_RFy_kN.png
# ...

# %%
numero_image = 4

top_horiz = widgets.IntSlider(
    value=500,
    min=0,
    max=1080,
    step=10,
    description='Top:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='d'
)
bottom_horiz = widgets.IntSlider(
    value=1440,
    min=0,
    max=1440,
    step=10,
    description='Bottom:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='d'
)
left_vert = widgets.IntSlider(
    value=500,
    min=0,
    max=1920,
    step=10,
    description='Left:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='d'
)
right_vert = widgets.IntSlider(
    value=1650,
    min=0,
    max=1920,
    step=10,
    description='Right:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='d'
)

# Create a function to show the image with horizontal red lines
def show_image(top, bottom, left, right):
    img = mpimg.imread(imgs[numero_image])
    plt.imshow(img)
    plt.axhline(y=top, color='r', linestyle='-', linewidth=2)
    plt.axhline(y=bottom, color='r', linestyle='-', linewidth=2)
    plt.axvline(x=left_vert.value, color='r', linestyle='-', linewidth=2)
    plt.axvline(x=right_vert.value, color='r', linestyle='-', linewidth=2)
    plt.show()

interact(show_image, top=top_horiz, bottom=bottom_horiz, left=left_vert, right=right_vert)
# Out:
# interactive(children=(IntSlider(value=500, continuous_update=False, description='Top:', max=1080, step=10), In…
# <function __main__.show_image(top, bottom, left, right)>

# %%
crop_image(img_path=imgs[numero_image], top=top_horiz.value, bottom=bottom_horiz.value, left=left_vert.value, right=right_vert.value, show=True)

# %%
for im in glob.glob('assets/img/*.png'):
    print(im)
    if ('3D' in im) and 'cropped' not in im:    
        crop_image(img_path=im, top=500, bottom=1440, left=500, right=1650, show=True)
